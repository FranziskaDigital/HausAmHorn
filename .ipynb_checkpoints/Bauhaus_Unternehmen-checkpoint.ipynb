# %%
import folium
# Out:
# /Users/franziskaklemstein/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import pandas as pd

# %%
unternehmen = pd.read_csv("Unternehmen.csv", delimiter=";")
personen = pd.read_csv("Personen.csv", delimiter=";")
gegenstaende = pd.read_csv("Gegenstände.csv", delimiter=";")

map = folium.Map(location=[51.1657, 10.4515], zoom_start=6)

# %%
for _, row in unternehmen.iterrows():
    # Popup-Text erstellen
    popup_html = f"""
    <b>Unternehmen:</b> {row['Name']}<br>
    <b>Standort:</b> {row['Standort']}<br>
    <b>Identifier:</b> <a href="{row['Identifier']}" target="_blank">Website</a><br>
    """
    
    # Verknüpfte Personen hinzufügen (aus Gegenstandstabelle)
    related_items = gegenstaende[gegenstaende['Unternehmen ID'] == row['ID']]
    if not related_items.empty:
        popup_html += "<b>Verknüpfte Personen:</b><ul>"
        for pid in related_items['Hersteller:innen ID'].values:
            for person_id in map(int, pid.split(',')):
                person_row = personen[personen['ID'] == person_id]
                if not person_row.empty:
                    person = person_row.iloc[0]
                    popup_html += f'<li><a href="{person["Identifier"]}" target="_blank">{person["Name"]}</a></li>'
        popup_html += "</ul>"

    # Marker hinzufügen
    folium.Marker(
        location=[row['Breitengrad'], row['Längengrad']],
        popup=folium.Popup(popup_html, max_width=300),
        tooltip=row['Name']
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40a0806d2037005c9d134f7fa3042d7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40a0806d2037005c9d134f7fa3042d7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40a0806d2037005c9d134f7fa3042d7c = L.map(
#                 &quot;map_40a0806d2037005c9d134f7fa3042d7c&quot;,
#                 {
#                     center: [51.1657, 10.4515],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d23be12fa2c3bca354c9692a491c4e4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d23be12fa2c3bca354c9692a491c4e4b.addTo(map_40a0806d2037005c9d134f7fa3042d7c);
#
#
#             var marker_a12a3748dab6a82882011993a80002a1 = L.marker(
#                 [53543.0, 9998.0],
#                 {}
#             ).addTo(map_40a0806d2037005c9d134f7fa3042d7c);
#
#
#         var popup_b79c4ec7878b31ee5aef02c86c03c77e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_b3e1adfa78d5880df660c65feefce93f = $(`&lt;div id=&quot;html_b3e1adfa78d5880df660c65feefce93f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Unternehmen:&lt;/b&gt; Triton Werke Hamburg&lt;br&gt;     &lt;b&gt;Standort:&lt;/b&gt; Hamburg&lt;br&gt;     &lt;b&gt;Identifier:&lt;/b&gt; &lt;a href=&quot;https://www.wikidata.org/wiki/Q107017368&quot; target=&quot;_blank&quot;&gt;Website&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_b79c4ec7878b31ee5aef02c86c03c77e.setContent(html_b3e1adfa78d5880df660c65feefce93f);
#
#
#
#         marker_a12a3748dab6a82882011993a80002a1.bindPopup(popup_b79c4ec7878b31ee5aef02c86c03c77e)
#         ;
#
#
#
#
#             marker_a12a3748dab6a82882011993a80002a1.bindTooltip(
#                 `&lt;div&gt;
#                      Triton Werke Hamburg
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25c1e9ee3c46f7feb2d5a1b3bfa0f552 = L.marker(
#                 [51.83066, 12.24306],
#                 {}
#             ).addTo(map_40a0806d2037005c9d134f7fa3042d7c);
#
#
#         var popup_6c2e6a5f69ef1bc006e7159cf1b9661b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f5d9d998233f9645f59f93541a4385fb = $(`&lt;div id=&quot;html_f5d9d998233f9645f59f93541a4385fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Unternehmen:&lt;/b&gt; Junkers &amp; Co. Dessau&lt;br&gt;     &lt;b&gt;Standort:&lt;/b&gt; Dessau&lt;br&gt;     &lt;b&gt;Identifier:&lt;/b&gt; &lt;a href=&quot;https://www.wikidata.org/wiki/Q1713670&quot; target=&quot;_blank&quot;&gt;Website&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_6c2e6a5f69ef1bc006e7159cf1b9661b.setContent(html_f5d9d998233f9645f59f93541a4385fb);
#
#
#
#         marker_25c1e9ee3c46f7feb2d5a1b3bfa0f552.bindPopup(popup_6c2e6a5f69ef1bc006e7159cf1b9661b)
#         ;
#
#
#
#
#             marker_25c1e9ee3c46f7feb2d5a1b3bfa0f552.bindTooltip(
#                 `&lt;div&gt;
#                      Junkers &amp; Co. Dessau
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd334a4d728e6275937c28da4d6cc055 = L.marker(
#                 [52.2031, 8.5814],
#                 {}
#             ).addTo(map_40a0806d2037005c9d134f7fa3042d7c);
#
#
#         var popup_ffdb388962474e70b794b20c8d0c4946 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f8fd1cf00389efb3dac8e9b070dde49d = $(`&lt;div id=&quot;html_f8fd1cf00389efb3dac8e9b070dde49d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Unternehmen:&lt;/b&gt; Imperial Bünde Westf.&lt;br&gt;     &lt;b&gt;Standort:&lt;/b&gt; Bünde&lt;br&gt;     &lt;b&gt;Identifier:&lt;/b&gt; &lt;a href=&quot;https://www.wikidata.org/wiki/Q1660275&quot; target=&quot;_blank&quot;&gt;Website&lt;/a&gt;&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_ffdb388962474e70b794b20c8d0c4946.setContent(html_f8fd1cf00389efb3dac8e9b070dde49d);
#
#
#
#         marker_bd334a4d728e6275937c28da4d6cc055.bindPopup(popup_ffdb388962474e70b794b20c8d0c4946)
#         ;
#
#
#
#
#             marker_bd334a4d728e6275937c28da4d6cc055.bindTooltip(
#                 `&lt;div&gt;
#                      Imperial Bünde Westf.
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a76086a2ecd5ff0151e490af6bc5ade0 = L.marker(
#                 [51.92825, 9.89697],
#                 {}
#             ).addTo(map_40a0806d2037005c9d134f7fa3042d7c);
#
#
#         var popup_6a175c13ff87e4baf4b0826d7b34b51d = L.popup({&quot;maxWidth&quot;: 300});
